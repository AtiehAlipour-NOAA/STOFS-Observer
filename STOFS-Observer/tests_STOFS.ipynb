# %%
from _STOFS import get_station_nowcast_data
from _STOFS import get_station_data

# %%
filename = 'points.cwl'
modelname = 'stofs_2d_glo'
directoryname = ''
bucketname = 'noaa-gestofs-pds'
daterange = ['20240922', '20240923']
steps = 60
cycles = ['00','06','12','18']

STOFS_2D_Nowcast = get_station_nowcast_data(filename, modelname, directoryname, bucketname,daterange, steps, cycles)
STOFS_2D_Nowcast
# Out:
# <xarray.Dataset> Size: 60MB
# Dimensions:       (time: 481, station: 1688)
# Coordinates:
#   * time          (time) datetime64[ns] 4kB 2024-09-22 ... 2024-09-24
# Dimensions without coordinates: station
# Data variables:
#     station_name  (time, station) |S50 41MB b'PSBM1 SOUS41 8410140 ME Eastpor...
#     x             (time, station) float64 6MB -66.98 -67.2 ... -51.01 -25.5
#     y             (time, station) float64 6MB 44.9 44.65 44.39 ... 58.96 58.96
#     zeta          (time, station) float64 6MB -3.29 -2.433 ... 0.3197 0.06017
# Attributes: (12/50)
#     dry_Value:          -99999.0
#     model:              ADCIRC
#     version:            noaa.stofs.2d.glo.v2.1.0r1.v55.12
#     git_hash:           23947fbd9683d0ef48f12e6ce62d45d18bc27ff3
#     grid_type:          Triangular
#     description:        2024092200 :-6 hr nowcast and +180 hr forecast ! 32 C...
#     ...                 ...
#     sfea0:              45.0
#     cf:                 0.0005
# ...

# %%
filename = 'points.cwl.noanomaly'
modelname = 'stofs_2d_glo'
directoryname = ''
bucketname = 'noaa-gestofs-pds'
daterange = ['20240922', '20240923']
steps = 60
cycles = ['00','06','12','18']

STOFS_2D_Nowcast = get_station_nowcast_data(filename, modelname, directoryname, bucketname,daterange, steps, cycles)
STOFS_2D_Nowcast
# Out:
# <xarray.Dataset> Size: 60MB
# Dimensions:       (time: 481, station: 1688)
# Coordinates:
#   * time          (time) datetime64[ns] 4kB 2024-09-22 ... 2024-09-24
# Dimensions without coordinates: station
# Data variables:
#     station_name  (time, station) |S50 41MB b'PSBM1 SOUS41 8410140 ME Eastpor...
#     x             (time, station) float64 6MB -66.98 -67.2 ... -51.01 -25.5
#     y             (time, station) float64 6MB 44.9 44.65 44.39 ... 58.96 58.96
#     zeta          (time, station) float64 6MB -3.09 -2.373 ... 0.3197 0.06017
# Attributes: (12/51)
#     _FillValue:         -99999.0
#     dry_Value:          -99999.0
#     model:              ADCIRC
#     version:            noaa.stofs.2d.glo.v2.1.0r1.v55.12
#     git_hash:           23947fbd9683d0ef48f12e6ce62d45d18bc27ff3
#     grid_type:          Triangular
#     ...                 ...
#     sfea0:              45.0
#     cf:                 0.0005
#     eslm:               -0.2
#     cori:               0.0
# ...

# %%
filename = 'points.cwl'
modelname = 'stofs_3d_atl'
directoryname = 'STOFS-3D-Atl'
bucketname = 'noaa-nos-stofs3d-pds'
daterange = ['20240922', '20240923']
steps = 240
cycles = ['12']

STOFS_3D_Nowcast = get_station_nowcast_data(filename, modelname, directoryname, bucketname,daterange, steps, cycles)
STOFS_3D_Nowcast
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:       (time: 481, station: 108)
# Coordinates:
#   * time          (time) datetime64[ns] 4kB 2024-09-22 ... 2024-09-24
# Dimensions without coordinates: station
# Data variables:
#     zeta          (time, station) float64 416kB -3.063 -2.686 ... 0.1925 0.4361
#     station_name  (time, station) |S50 3MB b'PSBM1 SOUS41 8410140 ME Eastport...
#     x             (time, station) float64 416kB 44.9 44.66 43.66 ... 26.06 27.83
#     y             (time, station) float64 416kB -66.98 -67.2 ... -97.22 -97.49
#     u             (time, station) float64 416kB 1.596 0.006648 ... -0.823 -999.0
#     v             (time, station) float64 416kB 0.4976 -0.03024 ... -999.0
#     salinity      (time, station) float64 416kB 32.2 32.77 ... 32.12 -999.0
#     temperature   (time, station) float64 416kB 12.01 12.52 ... 25.84 -999.0
# Attributes:
#     title:       SCHISM Model output
#     source:      SCHISM model output version v10
# ...

# %%
filename = 'points.cwl'
modelname = 'stofs_2d_glo'
directoryname = ''
bucketname = 'noaa-gestofs-pds'
date = '20240922'
cycle = '00'

STOFS_2D_Forecast = get_station_data(filename, modelname, directoryname, bucketname, date, cycle)
STOFS_2D_Forecast
# Out:
# <xarray.Dataset> Size: 25MB
# Dimensions:       (time: 1860, station: 1688)
# Coordinates:
#   * time          (time) datetime64[ns] 15kB 2024-09-21T18:06:00 ... 2024-09-...
# Dimensions without coordinates: station
# Data variables:
#     station_name  (station) |S50 84kB ...
#     x             (station) float64 14kB ...
#     y             (station) float64 14kB ...
#     zeta          (time, station) float64 25MB ...
# Attributes: (12/50)
#     dry_Value:          -99999.0
#     model:              ADCIRC
#     version:            noaa.stofs.2d.glo.v2.1.0r1.v55.12
#     git_hash:           23947fbd9683d0ef48f12e6ce62d45d18bc27ff3
#     grid_type:          Triangular
#     description:        2024092200 :-6 hr nowcast and +180 hr forecast ! 32 C...
#     ...                 ...
#     sfea0:              45.0
#     cf:                 0.0005
#     eslm:               -0.2
#     cori:               0.0
#     ntif:               8
#     nbfr:               0
